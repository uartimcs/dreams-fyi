# %%
# !pip install synthtiger
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 kB 4.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.2/171.2 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for blend-modes: filename=blend_modes-2.1.0-py3-none-any.whl size=9539 sha256=e5a7186da23dddd4d8617eee59c9037445ac0d68156130453c0bf024c441dc30
#   Stored in directory: /root/.cache/pip/wheels/68/59/0f/7f3f9e6e1fcbbaf41376ce408a4d1f14df7546bad2ced90fd4
# ...
#   Created wheel for pytweening: filename=pytweening-1.2.0-py3-none-any.whl size=8011 sha256=43ac7c38e8df3c0cdf05806050b0c662a87192a8aa505c2d73a29c1a2a801b5d
#   Stored in directory: /root/.cache/pip/wheels/22/d7/02/b3e395d93b6dd41a7da54b2fa738ec03e7fb7451f7f22f8213
# Successfully built blend-modes pytweening
# ...

# %%
# !git clone https://github.com/clovaai/donut.git
# Out:
# Cloning into 'donut'...
# remote: Enumerating objects: 289, done.
# remote: Total 289 (delta 0), reused 0 (delta 0), pack-reused 289
# Receiving objects: 100% (289/289), 62.76 MiB | 33.40 MiB/s, done.
# Resolving deltas: 100% (135/135), done.

# %%
# %cd /content/donut/synthdog
# !ls -l
# Out:
# /content/donut/synthdog
# total 40
# -rwxr-xr-x 1 root root 2477 Feb 28 01:25 config_en.yaml
# -rwxr-xr-x 1 root root 2477 Feb 28 01:25 config_ja.yaml
# -rwxr-xr-x 1 root root 2477 Feb 28 01:25 config_ko.yaml
# -rwxr-xr-x 1 root root 2477 Feb 28 01:25 config_zh.yaml
# drwxr-xr-x 2 root root 4096 Feb 28 01:25 elements
# drwxr-xr-x 2 root root 4096 Feb 28 01:25 layouts
# -rwxr-xr-x 1 root root 1584 Feb 28 01:25 README.md
# drwxr-xr-x 6 root root 4096 Feb 28 01:25 resources
# -rwxr-xr-x 1 root root 4937 Feb 28 01:25 template.py

# %%
# !synthtiger -o ./outputs/SynthDoG_en -c 50 -w 4 -v template.py SynthDoG config_en.yaml
# !synthtiger -o ./outputs/SynthDoG_ja -c 50 -w 4 -v template.py SynthDoG config_ja.yaml
# !synthtiger -o ./outputs/SynthDoG_ko -c 50 -w 4 -v template.py SynthDoG config_ko.yaml
# !synthtiger -o ./outputs/SynthDoG_zh -c 50 -w 4 -v template.py SynthDoG config_zh.yaml
# Out:
# {'config': 'config_en.yaml',
#  'count': 50,
#  'name': 'SynthDoG',
#  'output': './outputs/SynthDoG_en',
#  'script': 'template.py',
#  'seed': None,
#  'verbose': True,
#  'worker': 4}
# {'aspect_ratio': [1, 2],
#  'background': {'effect': {'args': [{'args': {'sigma': [0, 10]}, 'prob': 1}]},
#                 'image': {'paths': ['resources/background'], 'weights': [1]}},
#  'document': {'aspect_ratio': [1, 2],
#               'content': {'content_color': {'args': {'colorize': 1,
#                                                      'gray': [0, 64]},
#                                             'prob': 0.2},
#                           'font': {'bold': 0,
#                                    'paths': ['resources/font/en'],
#                                    'weights': [1]},
#                           'layout': {'align': ['left', 'right', 'center'],
#                                      'fill': [0.5, 1],
#                                      'full': 0.1,
# ...

# %%
# !zip -r ../outputs.zip ./outputs/
# Out:
#   adding: outputs/ (stored 0%)
#   adding: outputs/SynthDoG_zh/ (stored 0%)
#   adding: outputs/SynthDoG_zh/train/ (stored 0%)
#   adding: outputs/SynthDoG_zh/train/image_36.jpg (deflated 3%)
#   adding: outputs/SynthDoG_zh/train/metadata.jsonl (deflated 50%)
#   adding: outputs/SynthDoG_zh/train/image_40.jpg (deflated 5%)
#   adding: outputs/SynthDoG_zh/train/image_45.jpg (deflated 6%)
#   adding: outputs/SynthDoG_zh/train/image_43.jpg (deflated 8%)
#   adding: outputs/SynthDoG_zh/train/image_15.jpg (deflated 6%)
#   adding: outputs/SynthDoG_zh/train/image_16.jpg (deflated 4%)
#   adding: outputs/SynthDoG_zh/train/image_21.jpg (deflated 15%)
#   adding: outputs/SynthDoG_zh/train/image_17.jpg (deflated 8%)
#   adding: outputs/SynthDoG_zh/train/image_6.jpg (deflated 0%)
#   adding: outputs/SynthDoG_zh/train/image_27.jpg (deflated 14%)
#   adding: outputs/SynthDoG_zh/train/image_25.jpg (deflated 22%)
#   adding: outputs/SynthDoG_zh/train/image_29.jpg (deflated 4%)
# ...
